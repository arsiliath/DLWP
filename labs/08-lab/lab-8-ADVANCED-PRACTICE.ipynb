# %% [markdown]
# # Deep Dives & Best Practices

# %% [markdown]
# 1. Consider the following neural net:
#
#     ```python
#     model = keras.models.Sequential()
#     model.add(keras.Input((28, 28, 3)))
#     model.add(keras.layers.Conv2D(32, kernel_size=3, activation="relu"))
#     model.add(keras.layers.MaxPooling2D(pool_size=2))
#     model.add(keras.layers.Conv2D(64, kernel_size=3, activation="relu"))
#     model.add(keras.layers.MaxPooling2D(pool_size=2))
#     model.add(keras.layers.Conv2D(128, kernel_size=3, activation="relu"))
#     model.add(keras.layers.MaxPooling2D(pool_size=2))
#     model.add(keras.layers.Flatten())
#     model.add(keras.layers.Dense(512, activation="relu"))
#     model.add(keras.layers.Dense(10, activation="softmax"))
#     model.compile()
#     model.summary()
#     ```
#
# 2. Rewrite it using functional code.
# 4. Add an extra convolutional layer of 128 filters with `kernel_size` 3 before the `Flatten` layer.
# 5. Add a residual connection between the two 128 filter layers. Hint: specify `padding='same'` to guarantee shape compatibility.
# 6. Compile and train on MNIST using one or more callbacks, such as `keras.callbacks.ModelCheckpoint`, `keras.callbacks.EarlyStopping` or `keras.callbacks.EarlyStopping`.
# 7. Try adding batch normalisation.
#
# Optional: check out the [`lab-8-TPU.ipynb`](https://github.com/jchwenger/DLWP/blob/main/labs/08-lab/lab-8-TPU.ipynb). Encapsulate your net so as to run it using TPU acceleartion (note: these days TPU availability in Google Colab is quite irregular.)
