# %% [markdown]
# # Language models and the Transformer

# %% [markdown]
# ## Sequence-to-sequence learning with a Transformer

# %% [markdown]
# Port the translation dataset code and train the full transformer (encoder/decoder) on it.
#
# Experiments:
# - Experiment with various hyperparameters.
# - Can you encapsulate your Transformer model so that it is easier to change its architecture (number of layers, number of heads, etc.)?
# - Train an RNN variant (LSTM or GRU) on the same dataset, and compare its performance with your Transformer.
#
# Note: What would it take for the final Transformer model to be trained on more than one language?

# %% [markdown]
# ## Classification with a Transformer

# %% [markdown]
# 1. Download the data and load it into datasets as is done in "Preparing the data" [here](https://github.com/jchwenger/DLWP/blob/main/lectures/08/chapter15_language-models-and-the-transformer.ipynb).
#
#     Note that if you work locally, and already downloaded this data for previous experiments, you can create a symlink:
#     ```bash
#     ln -s path/to/aclImdb [newName]
#     ```
#
# 2. Import the code for text classification with the Transformer Encoder and train it.
#
# 3. Experiment with different hyperparameters. How do the results compare with the first method we used in Chapter 4 (you can find experiments in the lecture notebook [here](https://github.com/jchwenger/DLWP/blob/main/lectures/03/chapter04_classification-and-regression.1.imdb.ipynb))?
#
# 4. Suggestions for experiments:
#     - Recalling the steps from last week, in [Chapter 14](https://github.com/jchwenger/DLWP/blob/main/lectures/07/chapter14_text-classification.ipynb): how does the Transformer architecture compare with ngram models or LSTMs, in terms of performance / speed? Can you explain why?
#     - Can you modify and encapsulate your Transformer model so that it is easier to change its architecture (number of layers, number of heads, etc.)?

# %% [markdown]
# ---

# %% [markdown]
# #### Remember to run your best performing models on the test set.
