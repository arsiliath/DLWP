# %% [markdown]
# Autoregressive: self prediction
# So: token 2 is from token 1, token 3 is from token 1-2, etc.
#
# *Attention is all you need* context
# - they were working with RNNs
# - added transformers
# - turns out you don't need RNNs
# - Attention is all you need
#
#
# So translation was working like:
#
# ENCODE
# <START> + tokens -> embeddings -> RNN encodes entire sequence into a single hidden state vector
#
# DECODE
# another rnn (autoregressive) does a loop around the hidden state fector (beginning with <START>) so its
# prev output token -> rnn -> softmax on vocab (basically a classifier) ->  token -> autoregress
