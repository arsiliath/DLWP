# %% [markdown]
# autoencoders
#
# input → compress → decompress → try to match the original input.
#
#
# they were initially used for denoising and dimensional analysis
#
# like image denoising
#
# noisy, not noisy
#
# and then image is the noisy and decoded output y is not noisy
#
# crucially, you use the full autoencoder (not just the decoder) for denoising
#
# if you just use decoder, it's more for image generation
